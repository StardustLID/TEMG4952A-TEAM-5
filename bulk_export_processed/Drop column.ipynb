# %%
import pandas as pd

# %%
df = pd.read_csv("jobs_processed_1.csv") # change the input CSV name

keep_col = ['uuid','permalink','created_at','updated_at','person_uuid','person_name',
            'org_uuid','org_name',
            'started_on','ended_on','is_current', "title", "job_type"] # change the cols to keep

drop_row = [0, 1] # change the rows to drop

new_df = df[keep_col].drop(drop_row)
new_df.to_csv("jobs_edited.csv", index=False) # change the output CSV name

# %%
new_df
# Out:
#                                         uuid  \
# 2       1319cd30-f5e8-c700-0af6-64029c6f7124
# 3       27a252de-1ea8-c620-b2d4-5b889fa9b40f
# 4       5a802a79-229f-44ae-0aba-db330f10b67a
# 5       423205d5-feb5-06e3-8bb0-67fe5c3ddf7a
# 6       55aa1e54-d21e-1697-9892-c07ef2fa8b10
# ...                                      ...
# 337535  39d0b052-87e2-8263-b054-48c29cceda4f
# 337536  8f2d1102-7c3d-0ff3-fefe-74c6b332002f
# 337537  17cebf8b-b67c-872d-9f6f-139dc8960772
# 337538  b2ca83d0-a28f-f40e-e4f7-cdbc693cb052
# 337539  15c289df-63b7-d19a-447e-9e25596428a5
#
#                                                 permalink  \
# 2                    raju-vegesna-employee-zoho--1319cd30
# 3                      ian-wenig-executive-zoho--27a252de
# 4                    jay-adelson-executive-digg--5a802a79
# 5                      owen-byrne-employee-digg--423205d5
# 6                 ron-gorodetzky-executive-digg--55aa1e54
# ...                                                   ...
# ...

# %%
df = pd.read_csv("jobs_processed_2.csv", names= new_df.columns) # change the input CSV name

# %%
df
# Out:
#             uuid                             permalink  \
# 0       l Santos  feac3cfa-21ba-11bf-faab-a1bba95fce6e
# 1         337540  78a94437-cbce-026f-e961-efeb61673e9e
# 2         337541  e3ac5929-09b8-8b14-50e5-7f06845a9356
# 3         337542  d4d3f97c-88bc-51ec-efe0-caca71903beb
# 4         337543  754ad0a5-bb78-9b9d-82b8-6ea64d00c8e0
# ...          ...                                   ...
# 337978    675517  17598e14-6235-3c96-2dc1-c3352efeb0ff
# 337979    675518  a34e3058-fa34-82c0-d66d-e70157a2c9e8
# 337980    675519  e9eda120-37a1-6ca7-d26c-0887db0206ac
# 337981    675520  e06d0593-b70d-d55b-552f-e74ccd792efa
# 337982    675521  e6f1fa16-be01-c472-2c4c-41144b0456a6
#
#                                                created_at  \
# 0                                                  PEAR'd
# 1                  james-meyer-executive-urbful--78a94437
# 2                peyton-sandoz-executive-urbful--e3ac5929
# 3           richard-bexon-executive-namu-travel--d4d3f97c
# ...
