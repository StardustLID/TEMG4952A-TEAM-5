# %%
import pandas as pd

# %%
df1 = pd.read_csv("event_appearances_processed_1.csv") # change the input CSV name
df2 = pd.read_csv("event_appearances_processed_2.csv",names = df1.columns) # change the input CSV name
# df3 = pd.read_csv("jobs_processed_3.csv",  names = df1.columns) # change the input CSV name
# df4 = pd.read_csv("jobs_processed_4.csv", names = df1.columns) # change the input CSV name
# df5 = pd.read_csv("jobs_processed_5.csv", names = df1.columns) # change the input CSV name
df1
# Out:
#         Unnamed: 0                                  uuid  \
# 0                0  30c4023d-b694-4704-97d7-cd99cd06ecce
# 1                1  dffe0542-3dac-4228-a997-3eed42cbd67e
# 2                2  21884e6c-d097-4c54-8513-10536a0ea60d
# 3                3  c3782f8f-4684-47d6-8649-d0b3e1825eb5
# 4                4  55e2ee8b-b5b7-49d3-bd21-a63eedf6b7f2
# ...            ...                                   ...
# 329974      329974  b0f346a9-c962-49c7-ae9c-12cd3b73b86a
# 329975      329975  afde5966-5d29-4ca8-90f5-c936138b4a18
# 329976      329976  d575164d-f2f8-47e4-a8a9-992bafd8ab23
# 329977      329977  c0bb7427-f30f-4356-8f1d-f3f18b4cadc3
# 329978      329978  be2aafa6-950d-4a5e-9fdb-e98ffb62c920
#
#                                                      name  \
# 0              Adobe MAX 2014's sponsor - CDW Corporation
# 1                    Adobe MAX 2014's sponsor - Microsoft
# 2                      Adobe MAX 2014's sponsor - Twitter
# ...

# %%
keep_col = ['uuid','permalink','created_at','updated_at','event_uuid','event_name',
            'participant_uuid','participant_name',
            'participant_type','appearance_type'] # change the cols to keep

drop_row = [0, 1] # change the rows to drop

new_df = df2[keep_col].drop(drop_row)
new_df.to_csv("event_appearances_processed_2.csv", index=False) # change the output CSV name

# %%
df5 = pd.read_csv("event_appearances_processed_2.csv") # change the input CSV name
df5
# Out:
#                                        uuid  \
# 0      ff24969d-c702-4361-8176-49cc9a7e126b
# 1      f1814722-42d2-4ab1-b472-81c51424cb7e
# 2      59aa2479-ed70-490b-9ba7-2ca4ae2aaefc
# 3      2c79cf0f-8dc1-49d5-928f-1ba55c606c0f
# 4      02b1aa22-8767-4119-be31-aef7eec668fd
# ...                                     ...
# 83436  513b7641-60a0-48d4-ad81-2d814a7f8feb
# 83437  eb5fad66-a2ca-4d0d-99bc-f4d0aa46ecdb
# 83438  7355f052-67d4-47c8-93ba-5a23a59dd683
# 83439  732c9c23-605b-47af-a39c-21bdb0adb1b1
# 83440  93b46820-ed86-4b64-8816-90a45d25777c
#
#                                                permalink           created_at  \
# 0      julia-hartz-speaker-cannes-lions-international...  2019-06-18 10:26:36
# 1          scott-allen-3-speaker-ndc-oslo-2019--f1814722  2019-06-18 10:27:30
# 2      william-giard-speaker-hpe-discover-2019--59aa2479  2019-06-18 10:27:34
# 3      alicia-hatch-speaker-cannes-lions-internationa...  2019-06-18 10:29:26
# ...
