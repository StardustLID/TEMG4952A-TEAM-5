# %%
import pandas as pd

# %%
df1 = pd.read_csv("degrees.csv") # change the input CSV name
#df2 = pd.read_csv("event_appearances_processed_2.csv",names = df1.columns) # change the input CSV name
# df3 = pd.read_csv("jobs_processed_3.csv",  names = df1.columns) # change the input CSV name
# df4 = pd.read_csv("jobs_processed_4.csv", names = df1.columns) # change the input CSV name
# df5 = pd.read_csv("jobs_processed_5.csv", names = df1.columns) # change the input CSV name
df1
# Out:
#         Unnamed: 0                                  uuid    type  \
# 0                0  205fdfd1-ecac-aa43-262f-219f11755f67  degree
# 1                1  1a2ac288-eb99-3318-fde5-1517bc168f51  degree
# 2                2  b978d338-7ccc-7469-5ce7-ef98c34155ad  degree
# 3                3  d01cfaad-0ccc-631e-0382-1e507bf6ba04  degree
# 4                4  16a607f5-8ab3-573e-8d09-57b3e352e1d3  degree
# ...            ...                                   ...     ...
# 370027      370027  8079dc6e-6465-4b6d-838c-3f814bc117e2  degree
# 370028      370028  25720d58-edf2-4d4d-b7b3-303b01f0ab30  degree
# 370029      370029  16300cee-ea5a-481d-91ee-b69db61c57b4  degree
# 370030      370030  6d0dd169-a899-4174-9686-70f3cfc867f4  degree
# 370031      370031  4bfb1361-d872-4142-8f55-f19ad6afcc58  degree
#
#                  created_at           updated_at  \
# 0       2008-02-19 17:58:31  2018-02-13 01:40:03
# 1       2008-02-19 17:58:31  2018-02-13 01:39:57
# ...

# %%
keep_col = ['uuid','type','created_at','updated_at','person_uuid','person_name',
            'institution_uuid','institution_name',
            'degree_type','subject', "started_on", "completed_on", "is_completed"] # change the cols to keep

drop_row = [0, 1] # change the rows to drop

new_df = df1[keep_col].drop(drop_row)
new_df.to_csv("degrees.csv", index=False) # change the output CSV name

# %%
df5 = pd.read_csv("degrees.csv") # change the input CSV name
df5
# Out:
#                                         uuid    type           created_at  \
# 0       b978d338-7ccc-7469-5ce7-ef98c34155ad  degree  2008-02-19 23:40:40
# 1       d01cfaad-0ccc-631e-0382-1e507bf6ba04  degree  2008-02-21 01:31:01
# 2       16a607f5-8ab3-573e-8d09-57b3e352e1d3  degree  2008-02-21 01:31:34
# 3       0d199152-1aba-9ff2-151f-6a9ad279a1cf  degree  2008-02-22 08:16:50
# 4       62cb9fa9-30b8-4b11-cebf-643208fc2e06  degree  2008-02-22 08:27:15
# ...                                      ...     ...                  ...
# 370025  8079dc6e-6465-4b6d-838c-3f814bc117e2  degree  2020-12-30 22:40:34
# 370026  25720d58-edf2-4d4d-b7b3-303b01f0ab30  degree  2020-12-30 22:40:34
# 370027  16300cee-ea5a-481d-91ee-b69db61c57b4  degree  2020-12-30 23:41:39
# 370028  6d0dd169-a899-4174-9686-70f3cfc867f4  degree  2020-12-30 23:51:50
# 370029  4bfb1361-d872-4142-8f55-f19ad6afcc58  degree  2020-12-30 23:51:50
#
#                  updated_at                           person_uuid  \
# ...
