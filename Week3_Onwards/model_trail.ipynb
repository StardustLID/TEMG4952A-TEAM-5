# %% [markdown]
# Analysing with Decision tree
# Setup: put it in the same folder as "unifed_csv_without_duplicated_company.csv" and "ROI.csv" (generated by get_roi notebook)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split   
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, VotingClassifier 
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from IPython.display import Image
import pydotplus
import graphviz
from sklearn.model_selection import GridSearchCV

# Optional
# import library for visuaiization
from sklearn import tree
import matplotlib.pyplot as plt
from collections import Counter

# %%
#Read both CSV
ROI_df= pd.read_csv("ROI.csv")
df=pd.read_csv("unifed_csv_without_duplicated_company.csv")
df.info(max_cols=1000)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37198 entries, 0 to 37197
# Data columns (total 104 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   company_uuid                        37198 non-null  object
#  1   company_name                        347 non-null    object
#  2   country_code                        33609 non-null  object
#  3   region                              33609 non-null  object
#  4   city                                33609 non-null  object
#  5   status                              37198 non-null  object
#  6   category_groups_list                37198 non-null  object
#  7   num_funding_rounds                  12036 non-null  float64
#  8   total_funding_usd                   9093 non-null   float64
#  9   founded_on                          37198 non-null  object
#  10  last_funding_on                     12032 non-null  object
#  11  closed_on                           591 non-null    object
#  12  employee_count                      37198 non-null  object
#  13  primary_role                        37198 non-null  object
#  14  num_exits                           1912 non-null   float64
#  15  categories                          37198 non-null  object
#  16  Financial Services                  37198 non-null  int64
#  17  FinTech                             37198 non-null  int64
#  18  Finance                             37198 non-null  int64
#  19  Blockchain                          37198 non-null  int64
#  20  Information Technology              37198 non-null  int64
#  21  Software                            37198 non-null  int64
#  22  Payments                            37198 non-null  int64
#  23  Cryptocurrency                      37198 non-null  int64
#  24  Venture Capital                     37198 non-null  int64
#  25  Internet                            37198 non-null  int64
#  26  Banking                             37198 non-null  int64
#  27  Consulting                          37198 non-null  int64
#  28  Mobile Payments                     37198 non-null  int64
#  29  E-Commerce                          37198 non-null  int64
#  30  Insurance                           37198 non-null  int64
#  31  Bitcoin                             37198 non-null  int64
#  32  Artificial Intelligence             37198 non-null  int64
#  33  Mobile                              37198 non-null  int64
#  34  Crowdfunding                        37198 non-null  int64
#  35  SaaS                                37198 non-null  int64
#  36  Real Estate                         37198 non-null  int64
#  37  Apps                                37198 non-null  int64
#  38  Personal Finance                    37198 non-null  int64
#  39  Accounting                          37198 non-null  int64
#  40  Mobile Apps                         37198 non-null  int64
#  41  Asset Management                    37198 non-null  int64
#  42  Marketplace                         37198 non-null  int64
#  43  Lending                             37198 non-null  int64
#  44  Big Data                            37198 non-null  int64
#  45  Machine Learning                    37198 non-null  int64
#  46  fund_rd_country_code                11894 non-null  object
#  47  fund_rd_investment_type             12032 non-null  object
#  48  fund_rd_announced_on                12032 non-null  object
#  49  fund_rd_raised_amount_usd           8134 non-null   float64
#  50  fund_rd_post_money_valuation_usd    1029 non-null   float64
#  51  fund_rd_investor_count              8067 non-null   float64
#  52  investment_count                    571 non-null    float64
#  53  any_partner                         571 non-null    float64
#  54  any_top_partner                     7 non-null      float64
#  55  ipo_went_public_on                  347 non-null    object
#  56  ipo_share_price_usd                 79 non-null     float64
#  57  ipo_valuation_price_usd             54 non-null     float64
#  58  ipo_money_raised_usd                90 non-null     float64
#  59  funds_uuid                          1463 non-null   object
#  60  funds_raised_amount_usd             1177 non-null   float64
#  61  acquisitions_acquirer_uuid          1180 non-null   object
#  62  acquisitions_acquirer_name          1180 non-null   object
#  63  acquisitions_acquirer_country_code  1157 non-null   object
#  64  acquisitions_acquirer_region        1157 non-null   object
#  65  acquisitions_acquirer_city          1157 non-null   object
#  66  acquisitions_acquired_on            1180 non-null   object
#  67  acquisitions_price_usd              131 non-null    float64
#  68  parent_org_parent_uuid              818 non-null    object
#  69  event_count                         4227 non-null   float64
#  70  job_duration                        20522 non-null  float64
#  71  gender_male                         20522 non-null  float64
#  72  gender_female                       20522 non-null  float64
#  73  degree_type                         20522 non-null  float64
#  74  subject_Computer Science            20522 non-null  float64
#  75  subject_Economics                   20522 non-null  float64
#  76  subject_Finance                     20522 non-null  float64
#  77  subject_Electrical Engineering      20522 non-null  float64
#  78  subject_Business Administration     20522 non-null  float64
#  79  subject_Mechanical Engineering      20522 non-null  float64
#  80  subject_Marketing                   20522 non-null  float64
#  81  subject_Accounting                  20522 non-null  float64
#  82  subject_Law                         20522 non-null  float64
#  83  subject_Business                    20522 non-null  float64
#  84  subject_Computer Engineering        20522 non-null  float64
#  85  subject_Physics                     20522 non-null  float64
#  86  subject_Political Science           20522 non-null  float64
#  87  subject_Management                  20522 non-null  float64
#  88  subject_Engineering                 20522 non-null  float64
#  89  subject_Psychology                  20522 non-null  float64
#  90  subject_Mathematics                 20522 non-null  float64
#  91  subject_Chemical Engineering        20522 non-null  float64
#  92  subject_Chemistry                   20522 non-null  float64
#  93  subject_History                     20522 non-null  float64
#  94  subject_Biology                     20522 non-null  float64
#  95  subject_International Business      20522 non-null  float64
#  96  subject_Information Technology      20522 non-null  float64
#  97  subject_Business Management         20522 non-null  float64
#  98  subject_English                     20522 non-null  float64
#  99  subject_Industrial Engineering      20522 non-null  float64
#  100 subject_Civil Engineering           20522 non-null  float64
#  101 subject_Biochemistry                20522 non-null  float64
#  102 subject_Medicine                    20522 non-null  float64
#  103 subject_Philosophy                  20522 non-null  float64
# dtypes: float64(49), int64(30), object(25)
# memory usage: 29.5+ MB

# %%
#Create dataframe for features
features=df[["company_uuid", "status", "num_funding_rounds","Financial Services","FinTech","Finance","Blockchain", "Information Technology", "Software",  "Payments" , "Cryptocurrency", "Venture Capital","Internet", "Banking", "Consulting",  "Mobile Payments","E-Commerce", "Insurance", "Bitcoin", "Artificial Intelligence", "Mobile", "Crowdfunding","SaaS",  "Real Estate", "Apps", "Personal Finance","Accounting", "Mobile Apps", "Asset Management", "Marketplace", "Lending", "Big Data", "Machine Learning"]].copy()

# %%
#Deal with null value in num_funding_rounds and set status to number 
features['status'].replace(to_replace = ['operating', 'acquired','closed', "ipo"], value = [1,3,-1,2], inplace=True)
features["num_funding_rounds"]=features["num_funding_rounds"].fillna(0)

# %%
# Join with ROI.csv from ROI.ipynb
ROI_df=ROI_df.drop(columns=["Unnamed: 0","investment_delta", "norm_amount_delta", "max_norm_amount_delta" ])
features=features.set_index("company_uuid").join(ROI_df.set_index("org_uuid"))
features["mean_norm_amount_delta"]=features["mean_norm_amount_delta"].fillna(0)
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37198 entries, 0001a6ec-e7e9-4d1b-8a77-adb5ac815420 to ffffabce-6d4a-b3d1-13c0-4e90cedf5270
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   status                   37198 non-null  int64
#  1   num_funding_rounds       37198 non-null  float64
#  2   Financial Services       37198 non-null  int64
#  3   FinTech                  37198 non-null  int64
#  4   Finance                  37198 non-null  int64
#  5   Blockchain               37198 non-null  int64
#  6   Information Technology   37198 non-null  int64
#  7   Software                 37198 non-null  int64
#  8   Payments                 37198 non-null  int64
#  9   Cryptocurrency           37198 non-null  int64
#  10  Venture Capital          37198 non-null  int64
#  11  Internet                 37198 non-null  int64
#  12  Banking                  37198 non-null  int64
#  13  Consulting               37198 non-null  int64
#  14  Mobile Payments          37198 non-null  int64
#  15  E-Commerce               37198 non-null  int64
#  16  Insurance                37198 non-null  int64
#  17  Bitcoin                  37198 non-null  int64
#  18  Artificial Intelligence  37198 non-null  int64
#  19  Mobile                   37198 non-null  int64
#  20  Crowdfunding             37198 non-null  int64
#  21  SaaS                     37198 non-null  int64
#  22  Real Estate              37198 non-null  int64
#  23  Apps                     37198 non-null  int64
#  24  Personal Finance         37198 non-null  int64
#  25  Accounting               37198 non-null  int64
#  26  Mobile Apps              37198 non-null  int64
#  27  Asset Management         37198 non-null  int64
#  28  Marketplace              37198 non-null  int64
#  29  Lending                  37198 non-null  int64
#  30  Big Data                 37198 non-null  int64
#  31  Machine Learning         37198 non-null  int64
#  32  mean_norm_amount_delta   37198 non-null  float64
# dtypes: float64(2), int64(31)
# memory usage: 10.9+ MB

# %%
# define independent variables/attirbutes/features
x = features.drop(columns='mean_norm_amount_delta')
y = features["mean_norm_amount_delta"]

#Make "mean_norm_amount_delta" column 1/0
binary_labels = [0,1]
y = pd.qcut(y, 2, labels = binary_labels)
y
# Out:
# company_uuid
# 0001a6ec-e7e9-4d1b-8a77-adb5ac815420    0
# 0003f244-79d0-6178-353e-33dabaf3b2c6    0
# 00057beb-5724-c809-5cd2-a0a7c6b017aa    0
# 000ab460-8462-450d-ab34-b3c54fc252fd    0
# 000ad7a8-b868-f301-5f00-2a3361288fc9    0
#                                        ..
# fff9249a-baea-49a9-baca-a57b28ee7e6f    0
# fffa7546-aba8-5bbf-11a9-105d61b0dd0e    0
# fffbd05f-57b7-4fdc-94a6-be656719db8c    0
# fffe3b0b-8545-4414-9c0e-a3f961c4e420    0
# ffffabce-6d4a-b3d1-13c0-4e90cedf5270    1
# Name: mean_norm_amount_delta, Length: 37198, dtype: category
# Categories (2, int64): [0 < 1]

# %%
# Implement Decision tree
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=5)
model=DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# use the trained model to predict test set for evaluation
pred_test = model.predict(X_test)

# print out evaluation result
print("Accuracy:{}".format(accuracy_score(y_test, pred_test, normalize=True, sample_weight=None)))
print("Classification Report:\n{}".format(classification_report(y_test, pred_test)))
print("Confusion Matrix:\n{}".format(confusion_matrix(y_test, pred_test)))
# Out:
# Accuracy:0.9447132616487455
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     10431
#            1       0.60      0.46      0.52       729
#
#     accuracy                           0.94     11160
#    macro avg       0.78      0.72      0.74     11160
# weighted avg       0.94      0.94      0.94     11160
#
# Confusion Matrix:
# [[10210   221]
#  [  396   333]]
